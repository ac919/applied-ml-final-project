# %%
# !git clone https://github.com/ac919/applied-ml-final-project.git
# Out:
# fatal: destination path 'applied-ml-final-project' already exists and is not an empty directory.

# %%
# %cd /content/applied-ml-final-project
# !git lfs install
# !git lfs pull
# Out:
# /content/applied-ml-final-project

# %%
# %pip install -r requirements.txt

# %%
# process data
# !python data/data_loading.py

# %%
# training: man-zone model
# !python models/man_zone_transformer.py

# %%
# evaluation: man-zone model
# !python src/man_zone_eval.py

# %%
# training: multiclass model
# !python models/coverage_classifier_transformer.py

# %%
# evaluation: multiclass model
# !python src/coverage_classifier_eval.py
